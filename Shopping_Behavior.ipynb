# %% [markdown]
# ## Shopping_Behavior
#
# This project is to analyze analyze and predict the purchase amount based on customer features.

# %% [markdown]
# ## Importing the Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading The Dataset

# %%
df = pd.read_csv(r'C:\Users\Megha Nair\OneDrive\Desktop\projects to upload in github\Shopping Behavior\shopping_behavior_updated.csv')
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %% [markdown]
# ## Analysis of Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %% [markdown]
# ## Exploratory Data Analysis EDA

# %%
sns.boxplot(x = df['Age'],y = df['Frequency of Purchases'], data = df)
# Out:
# <Axes: xlabel='Age', ylabel='Frequency of Purchases'>

# %%
sns.countplot(x = df['Gender'],hue = df['Frequency of Purchases'], data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize=(10,20)) 
sns.countplot(y='Item Purchased', hue='Frequency of Purchases', data=df) 
plt.tight_layout() 
plt.show()

# %%
sns.countplot(x = 'Category',hue = df['Frequency of Purchases'], data = df)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
sns.barplot(x = 'Purchase Amount (USD)', y = 'Frequency of Purchases', data = df)
# Out:
# <Axes: xlabel='Purchase Amount (USD)', ylabel='Frequency of Purchases'>

# %%
plt.figure(figsize=(10,20)) 
sns.countplot(y = 'Location',hue = 'Frequency of Purchases', data = df) 
plt.tight_layout() 
plt.show()

# %%
sns.countplot(x = 'Size', hue = 'Frequency of Purchases', data = df)
# Out:
# <Axes: xlabel='Size', ylabel='count'>

# %%
plt.figure(figsize=(10,20)) 
sns.countplot(y = 'Color',hue = 'Frequency of Purchases', data = df)
# Out:
# <Axes: xlabel='count', ylabel='Color'>

# %%
plt.tight_layout() 
plt.show()
sns.countplot(x = 'Season', hue = 'Frequency of Purchases', data = df)
# Out:
# <Axes: xlabel='Season', ylabel='count'>

# %%
sns.barplot(x = 'Review Rating', y = 'Frequency of Purchases', data = df)
# Out:
# <Axes: xlabel='Review Rating', ylabel='Frequency of Purchases'>

# %%
sns.countplot(x = 'Subscription Status', hue = 'Frequency of Purchases', data = df)
# Out:
# <Axes: xlabel='Subscription Status', ylabel='count'>

# %%
plt.xticks(rotation =90) 
sns.countplot(x ='Shipping Type', hue = 'Frequency of Purchases', data = df)
# Out:
# <Axes: xlabel='Shipping Type', ylabel='count'>

# %%
sns.countplot(x = 'Discount Applied', hue = 'Frequency of Purchases', data = df)
# Out:
# <Axes: xlabel='Discount Applied', ylabel='count'>

# %%
sns.countplot(x = 'Promo Code Used', hue = 'Frequency of Purchases', data = df)
# Out:
# <Axes: xlabel='Promo Code Used', ylabel='count'>

# %%
sns.countplot(x = 'Payment Method', hue = 'Frequency of Purchases', data = df)
# Out:
# <Axes: xlabel='Payment Method', ylabel='count'>

# %% [markdown]
# **Converting Categorical Data to Numberical Data**

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
for column in df.columns:
    df[column] = LE.fit_transform(df[column])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   int32
#  3   Item Purchased          3900 non-null   int32
#  4   Category                3900 non-null   int32
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   int32
#  7   Size                    3900 non-null   int32
#  8   Color                   3900 non-null   int32
#  9   Season                  3900 non-null   int32
#  10  Review Rating           3900 non-null   int64
#  11  Subscription Status     3900 non-null   int32
#  12  Shipping Type           3900 non-null   int32
#  13  Discount Applied        3900 non-null   int32
# ...

# %%
df.drop('Customer ID', axis = 1,inplace = True)

# %%
plt.figure(figsize = (12,12))
sns.heatmap(df.corr(),annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## Modeling

# %%
final_res = []

# %%
x = df.drop('Frequency of Purchases', axis =1)
y = df['Frequency of Purchases']
## used for one hot encoder
#x = pd.get_dummies(x, drop_first=True)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2, random_state = 42)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (3120, 16) (780, 16) (3120,) (780,)

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
LR.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_LR = LR.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print('Logistic Regression :')
print('Accuracy Score',accuracy_score(y_test,y_pred_LR))
acc_LR = accuracy_score(y_test,y_pred_LR)
final_res.append(acc_LR)
# Out:
# Logistic Regression :
# Accuracy Score 0.14743589743589744

# %% [markdown]
# **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier()
DT.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_DT = DT.predict(x_test)

# %%
print('Decision Tree :')
print('Accuracy Score ',accuracy_score(y_test,y_pred_DT))
acc_DT = accuracy_score(y_test,y_pred_DT)
final_res.append(acc_DT)
# Out:
# Decision Tree :
# Accuracy Score  0.1358974358974359

# %% [markdown]
# **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier()
RF.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_RF = RF.predict(x_test)

# %%
print('Random Forest Classifier :')
print('Accuracy Score ',accuracy_score(y_test,y_pred_RF))
acc_RF = accuracy_score(y_test,y_pred_RF)
final_res.append(acc_RF)
# Out:
# Random Forest Classifier :
# Accuracy Score  0.14102564102564102

# %% [markdown]
# **K-Nearest Neighbors**

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier()
KNN.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_KNN = KNN.predict(x_test)

# %%
print('K Nearest Neighbors ')
print('Accuracy Score ',accuracy_score(y_test,y_pred_KNN))
acc_KNN = accuracy_score(y_test,y_pred_KNN)
final_res.append(acc_KNN)
# Out:
# K Nearest Neighbors
# Accuracy Score  0.1294871794871795

# %% [markdown]
# **XGBoost**

# %%
from xgboost import XGBClassifier
XGB = XGBClassifier()
XGB.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...)

# %%
y_pred_XGB = XGB.predict(x_test)

# %%
print('XGBoost ')
print('Accuracy Score ',accuracy_score(y_test,y_pred_XGB))
acc_XGB = accuracy_score(y_test,y_pred_XGB)
final_res.append(acc_XGB)
# Out:
# XGBoost
# Accuracy Score  0.13974358974358975

# %%
y_pred_XGB = XGB.predict(x_test)

# %% [markdown]
# **GradientBoosting**

# %%
from sklearn.ensemble import GradientBoostingClassifier
GBC = GradientBoostingClassifier()
GBC.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred_GBC = GBC.predict(x_test)

# %%
print('Gradient Boosting ')
print('Accuracy Score ',accuracy_score(y_test,y_pred_GBC))
acc_GBC = accuracy_score(y_test,y_pred_GBC)
final_res.append(acc_GBC)
# Out:
# Gradient Boosting
# Accuracy Score  0.14615384615384616

# %% [markdown]
# ## Comparing Algorithm

# %%
plt.xticks(rotation = 90)
sns.barplot(x = ['Logistic Regression', 'Random Forest','Decision Tree','K-Nearest Neighbors','GradientBoosting','XGBoost'], y = 
            [accuracy_score(y_test,y_pred_LR),accuracy_score(y_test,y_pred_RF),
             accuracy_score(y_test,y_pred_DT),accuracy_score(y_test,y_pred_KNN),
             accuracy_score(y_test,y_pred_GBC),accuracy_score(y_test,y_pred_XGB)])
# Out:
# <Axes: >

# %%
final = np.array(final_res)
result = final.reshape(-1,1)
columns=['Accuracy']
index = ['Logistic Regression', 'Random Forest','Decision Tree','K-Nearest Neighbors','GradientBoosting','XGBoost']
final_result = pd.DataFrame(result,index = index,columns = columns)
final_result.sort_values(by='Accuracy', ascending=False)
# Out:
#                      Accuracy
# Logistic Regression  0.147436
# XGBoost              0.146154
# Decision Tree        0.141026
# GradientBoosting     0.139744
# Random Forest        0.135897
# K-Nearest Neighbors  0.129487

# %% [markdown]
# ## Conclusion

# %% [markdown]
# After the model process with all I decided to select the Logistic Model as it gives the highest accuracy score.
